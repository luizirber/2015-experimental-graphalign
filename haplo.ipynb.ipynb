# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
primary = numpy.loadtxt('simple-haplo.counts', skiprows=1)
alt = numpy.loadtxt('simple-alt.counts', skiprows=1)

# %%
plot(primary[:,0], primary[:,1])
plot(alt[:,0], alt[:,1])
savefig('ex2.pdf')
